# %%
import pandas as pd
data = pd.Series([1,2,3,4])
print(data)
data = data.iloc[[3,0,1,2]]
print(data)
data = data.reset_index(drop=True)
print(data)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# 3    4
# 0    1
# 1    2
# 2    3
# dtype: int64
# 0    4
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
import numpy as np 

alphas = np.linspace(0, 1, 6)
alphas
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. ])

# %%
import pandas as pd

df = pd.read_csv('ds_events_fakes.csv', ';')
df.head()
# Out:
#      id                                             titulo  \
# 0    29                                       Viagem a Lua
# 1  4366             CAFÉ COM NEGÓCIOS |05ª EDIÇÃO CAMPINAS
# 2  4659  CURSO CERTIFICAÇÃO DPO – ASSESPRO-MG - Módulos...
# 3  4669  CURSO CERTIFICAÇÃO DPO – ASSESPRO-MG - Módulo ...
# 4  5399                           SUA EMPRESA EM EVIDÊNCIA
#
#                                            descricao  apenas_ingressos_gratis  \
# 0            Ida e volta @@Almoço e jantar incluídos                        0
# 1  <editado-web/><div style="width: 307.391px|| c...                        0
# 2  <editado-web/><p class="MsoNormal" align="cent...                        0
# 3  <editado-web/><p class="MsoNormal" align="cent...                        0
# 4  <editado-web/><p>2° Edição Sua empresa Em Evid...                        0
#
#    tem_banner                                    endereco_evento  \
# 0           1                 Cape Canaveral, Flórida 32920, EUA
# ...
